# %% [markdown]
# # 02 - Numpy, Pandas y Xarray
#
# Trabajaremos con arrays, DataFrames y DataArrays (xarray).

# %%
import numpy as np
import pandas as pd
import xarray as xr
print(np.__version__, pd.__version__, xr.__version__)

# %% [markdown]
# ## Numpy: operaciones vectorizadas

# %%
arr = np.array([10,20,30,40])
print('mean=', arr.mean(), 'std=', arr.std())

# %% [markdown]
# ## Pandas: tablas de observaciones

# %%
df = pd.DataFrame({'station':['CATAM','Rionegro','Cali'], 'temp':[18,20,28]})
print(df)
print('\nMedia por estación:\n', df.groupby('station').mean())

# %% [markdown]
# ## Xarray: manipular datos NetCDF (preview)

# %%
# Crear un DataArray de ejemplo
data = xr.DataArray(np.random.rand(4,5), dims=['lat','lon'])
print(data)
data.plot()
